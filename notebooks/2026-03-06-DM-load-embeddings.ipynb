# %% [markdown]
# # Load Embeddings
# In this notebook, we are demonstrate how to load in embeddings.

# %%
from hproj.data.paths import Paths

paths = Paths.from_env()
k100k_uni2 = paths.embedding("kather100k", "uni2")
k100k_uni2_train, k100k_uni2_test = k100k_uni2.load_splits()

# %%
print(k100k_uni2_train.describe())
print(k100k_uni2_test.describe())
# Out:
# {'features': '(100000, 1536), float32', 'labels': '(100000,), int64', 'metrics': {}}
# {'features': '(7180, 1536), float32', 'labels': '(7180,), int64', 'metrics': {}}
